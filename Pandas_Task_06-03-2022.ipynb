# %%
import os, PyPDF2
import pandas as pd

# %%
#read PDF file
from PyPDF2 import PdfFileReader
def read_pdf(pdf_path):
    with open(pdf_path, 'rb') as f:
        pdf = PdfFileReader(f)
        information = pdf.getDocumentInfo()
        no_of_pages = pdf.getNumPages()
        text=''
        for i in range(0,pdf.numPages):
            #Create Page Object
            pageObj = pdf.getPage(i)
            #extract text from PDF
            text = text + pageObj.extractText()
        return text

# %%
text_file = read_pdf('C:\\Users\\HP\\Documents\\same-resume-year-wise-master\\3+.pdf')
text_file
# Out:
# ' \n \n \n \n \n \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'

# %%
text_file = read_pdf('C:\\Users\\HP\\Downloads\\technical specss.pdf')
text_file
# Out:
# ...
# '\x01„\x01}\x01\x10\x01µ\x01„\x01˚\x01u\x01˚\x01v\x01ı\x01}\x01(\x01}\x01v\x01\x10\x01„\x01˚\x01ı\x01˚\x01}\x01À\x01˚\x01„\x01o\x01}\x01\x10\x01l\n\x01ˆ\x01µ\x01„\x01]\x01v\x01P\x03ð\x03U\x03î\x03ì\x03î\x03ì\x03r\x03î\x03ì\x03î\x03í\n\x01’\x01˚\x01„\x01ˆ\x01˚\x01›\x01ı\x03W\x01µ\x01’\x01]\x01v\x01˚\x01’\x01’\x01˚\x01À\x01˚\x01o\x01}\x01›\x01u\x01˚\x01v\x01ı\x03~\n\x01}\x01v\x01\x10\x01„\x01˚\x01ı\x01˚\x01}\x01À\x01˚\x01„\x01o\x01}\x01\x10\x01l\x01›\x01˚\x01\x10\x01]\x01(\x01]\x01\x10\x01\x02\x01ı\x01]\x01}\x01v\x01Á\x01]\x01ı\x01Z\x01˚\x01o\x01]\x01À\x01˚\x01„\x01Ç\x01˚\x01„\x01u\x01’\x03Ÿ\x01}\x01v\x01ˆ\x01]\x01ı\x01]\x01}\x01v\x01’\x03W\n\x01µ\x01v\x01\x10\x01ı\x01]\x01}\x01v\x01\x02\x01o\x01]\x01ı\x01Ç\x03W\n\x01}\x01›\x01„\x01}\x01À\x01]\x01ˆ\x01˚\x03î\x03ì\x01u\x01u\x01\x02\x01v\x01ˆ\x03î\x03ñ\x01u\x01u\x01\x10\x01o\x01˚\x01\x02\x01„\x01\x10\x01}\x01À\x01˚\x01„\x01ı\x01}\x01ı\x01Z\x01˚\x01„\x01˚\x01]\x01v\x01(\x01}\x01„\x01\x10\x01˚\x01u\x01˚\x01v\x01ı\x01\x0f\x01\x02\x01„\x01’\
# ...

# %%
text_file = read_pdf('C:\\Users\\HP\\Desktop\\Headphones invoice.pdf')
text_file
# Out:
# " \nTax Invoice/Bill of Supply/Cash Memo\n(Original for Recipient)\n*ASSPL-Amazon Seller Services Pvt. Ltd., ARIPL-Amazon Retail India Pvt. Ltd. (only where Amazon Retail India Pvt. Ltd. fulfillment center is co-located) \nCustomers desirous of availing input GST credit are requested to create a Business account and purchase on Amazon.in/business from Business eligible offers \nPlease note that this invoice is not a demand for payment\nPage \n1\n of \n1\nFor Appario Retail Private Ltd:\nAuthorized Signatory\nOrder Number:\n 407-4622346-3654702\nInvoice Number :\n HYD8-6899047\nOrder Date:\n 03.03.2022\nInvoice Details :\n TG-HYD8-1034-2122\nInvoice Date :\n 03.03.2022\nSl.\nNo\nDescription\nUnit\nPrice\nDiscount\nQty\nNet\nAmount\nTax\nRate\nTax\nType\nTax\nAmount\nTotal\nAmount\n\x02B\nBoult Audio Bass Buds Q2 Over-Ear Wired Lightweight\nStereo Headphones, Deep Bass & in-Built Mic, Headset with\nComfortable Ear Cushions, Long Cord (Black) |\nB08FY4FG5X ( B08FY4FG5X ) \nHSN:85183000\
# ...
